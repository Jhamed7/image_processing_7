# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
image = cv2.imread('tv.jpg', cv2.IMREAD_GRAYSCALE)
image.shape
# Out:
# (372, 620)

# %%
plt.imshow(image, cmap='gray')

# %%
hist = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
roi = image[70:290, 130:420]
plt.imshow(roi, cmap='gray')

# %%
def sp_noise(image,prob):
    '''
    Add salt and pepper noise to image
    prob: Probability of the noise
    '''
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

# %%
image_noisy = sp_noise(roi, 0.05)
plt.imshow(image_noisy, cmap='gray')

# %%
image[70:290, 130:420] = image_noisy
plt.imshow(image, cmap='gray')

# %% [markdown]
# ### Main code

# %%
image = cv2.imread('tv.jpg', cv2.IMREAD_GRAYSCALE)
rows, cols = image.shape
roi = image[60:290, 120:420]

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # .avi',cv2.VideoWriter_fourcc(*'DIVX')
writer = cv2.VideoWriter('TV_noise.mp4', fourcc, 20.0, (cols, rows))  # .mp4', fourcc
 
for i in range(100):
#     print(i)
    
    if i%10 == 0:
        out = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        writer.write(out)
    else:
        roi_noisy = sp_noise(roi, random.uniform(0.007, 0.01))
        image[60:290, 120:420] = roi_noisy
        out = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        writer.write(out)

writer.release()
